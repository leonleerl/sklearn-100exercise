# %%
# PCA（Principal Components Analysis）叫主成分分析技术，又称为主分量分析，旨在利用降维的思想，把多指标转换为少数几个综合指标
# 在统计学中，主成分分析PCA是一种简化数据集的技术
# 它是一个线性变换，这个变化把数据变换到一个新的坐标系统中，使得任何数据投影的第一大方差在第一个坐标（称第一主成分上），第二大方差在第二个坐标（第二主成分）上，以此类推。
# 主成分系经常用于减少数据集的维数，同时保持数据集对方差贡献最大的特征。

# %%
# 进行PCA降维前需要做数据标准化

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
np.random.seed(42)

# %%
df = pd.read_csv("./pca.csv")

# %%
df
# Out:
#          var1      var2      var3  class
# 0    5.248357  1.571557  0.120279      2
# 1    4.930868  1.612157  0.170031      0
# 2    5.323844  1.716610  0.200262      1
# 3    5.761515  1.710760  0.202349      2
# 4    4.882923  1.224466  0.177497      2
# ..        ...       ...       ...    ...
# 195  5.192659  1.406165  0.174499      1
# 196  4.558071  1.157373  0.186506      1
# 197  5.076863  1.770774  0.151062      0
# 198  5.029104  1.477092  0.177785      2
# 199  4.428515  1.747563  0.218865      0
#
# [200 rows x 4 columns]

# %%
X = df.copy()

# %%
y = X.pop("class")

# %%
X
# Out:
#          var1      var2      var3
# 0    5.248357  1.571557  0.120279
# 1    4.930868  1.612157  0.170031
# 2    5.323844  1.716610  0.200262
# 3    5.761515  1.710760  0.202349
# 4    4.882923  1.224466  0.177497
# ..        ...       ...       ...
# 195  5.192659  1.406165  0.174499
# 196  4.558071  1.157373  0.186506
# 197  5.076863  1.770774  0.151062
# 198  5.029104  1.477092  0.177785
# 199  4.428515  1.747563  0.218865
#
# [200 rows x 3 columns]

# %%
y
# Out:
# 0      2
# 1      0
# 2      1
# 3      2
# 4      2
#       ..
# 195    1
# 196    1
# 197    0
# 198    2
# 199    0
# Name: class, Length: 200, dtype: int64

# %%
scaler = StandardScaler()

# %%
X_std = scaler.fit_transform(X)

# %%
X_std
# Out:
# array([[ 5.78766514e-01,  2.76190961e-01, -1.52162464e+00],
#        [-1.04981285e-01,  4.82377166e-01, -5.18095954e-01],
#        [ 7.41336446e-01,  1.01284857e+00,  9.16730269e-02],
#        [ 1.68390811e+00,  9.83139884e-01,  1.33765444e-01],
#        [-2.08235092e-01, -1.48652939e+00, -3.67514555e-01],
#        [-2.08217413e-01, -1.03977521e+00,  7.14540148e-01],
#        [ 1.74440619e+00,  4.35909197e-01, -9.90329964e-01],
#        [ 8.70279710e-01,  4.34640254e-01, -5.72076404e-02],
#        [-4.61629869e-01,  4.35921811e-01,  2.07704993e-01],
#        [ 6.28133586e-01,  3.82603986e+00,  6.05205583e-01],
#        [-4.55107993e-01,  4.92641913e-01,  8.04061210e-01],
#        [-4.57597631e-01,  1.06618796e+00, -1.04783735e+00],
#        [ 3.04448485e-01,  8.81771756e-01, -1.46079739e+00],
#        [-2.01632684e+00,  5.74407302e-01,  1.37494498e+00],
#        [-1.81349730e+00, -4.07439208e-01,  4.21529387e-01],
#        [-5.61571500e-01,  6.83675296e-01, -6.68477628e-01],
#        [-1.04671897e+00, -8.72183278e-01,  1.65074965e+00],
#        [ 3.82285380e-01, -3.27756129e-01,  2.03044633e-01],
#        [-9.33862246e-01, -5.80205654e-01,  1.27572732e+00],
#        [-1.47687293e+00, -4.05679308e-03,  1.54478277e-01],
#        [ 1.62211989e+00,  2.26380416e+00,  2.16468643e+00],
#        [-1.99214619e-01, -1.98381666e+00,  1.85667783e+00],
#        [ 1.16617058e-01,  6.09824024e-01, -1.64700212e-01],
#        [-1.49027321e+00, -1.72526842e+00,  1.06623164e+00],
#        [-5.42291522e-01, -5.66562963e-01,  7.37258046e-01],
#        [ 1.63344337e-01,  1.01884060e+00,  1.46667448e+00],
#        [-1.19549295e+00, -2.19273130e-02, -8.86758203e-01],
#        [ 4.48455769e-01, -1.18189306e+00,  7.78280038e-01],
#        [-6.02868211e-01, -8.13758123e-01,  1.15382501e+00],
#        [-2.70194840e-01,  6.03056917e-01, -1.68733611e+00],
#        [-6.04018155e-01, -8.29057680e-01, -1.10695307e+00],
#        [ 2.03844427e+00,  1.32641948e-01, -1.97021809e+00],
#        [ 2.93684925e-02, -4.09293934e-02, -1.85317033e-01],
#        [-1.09504576e+00, -7.49053996e-01,  8.10039078e-01],
#        [ 9.29622615e-01,  2.09040780e+00,  1.60153908e+00],
#        [-1.27070784e+00,  5.56660588e-01,  1.61110594e-01],
#        [ 2.68807674e-01, -2.14417427e+00,  1.72887306e+00],
#        [-2.06627968e+00,  1.02166313e-01, -1.30547277e+00],
#        [-1.38629464e+00, -7.59400135e-01, -1.63150752e+00],
#        [ 2.55883477e-01,  7.78607710e-01,  3.03637955e-02],
#        [ 8.39086670e-01, -8.92188214e-01,  4.73721652e-01],
#        [ 2.28432543e-01, -2.03756081e-01,  5.34114121e-02],
#        [-8.06282489e-02,  4.25703357e-01, -1.99866831e+00],
#        [-2.80327514e-01,  7.92138853e-01, -3.49452070e-03],
#        [-1.54817710e+00, -1.30636994e+00, -1.22919656e+00],
#        [-7.31229276e-01, -4.26973330e-01,  7.61761608e-01],
#        [-4.52115637e-01, -5.69623749e-01,  4.56105660e-01],
#        [ 1.18221658e+00, -7.50810041e-01, -8.61501202e-01],
#        [ 4.13912165e-01,  1.70597196e+00, -4.31859474e-01],
#        [-1.85454760e+00,  3.24126724e-01, -9.81851445e-01],
#        [ 3.92877517e-01, -1.36790931e+00,  2.31716505e-02],
#        [-3.70756051e-01,  8.45064191e-01,  1.04966307e+00],
#        [-6.85010440e-01,  2.06827763e+00, -9.07737989e-01],
#        [ 7.02558285e-01,  9.61467896e-01,  5.94724741e-01],
#        [ 1.15408752e+00, -1.63045608e+00, -4.48389794e-01],
#        [ 1.04670920e+00, -5.79058435e-01, -7.13242014e-01],
#        [-8.59771026e-01,  1.19959688e+00, -2.15574047e-02],
#        [-2.89058979e-01, -8.06003947e-01, -9.57676054e-01],
#        [ 4.00608396e-01,  3.63574573e-01, -4.71980736e-01],
#        [ 1.09437397e+00,  6.99586220e-01, -1.12169699e+00],
#        [-4.72074715e-01, -1.02870949e+00,  2.06784570e+00],
#        [-1.56016095e-01, -1.47677642e-01,  1.21948594e-01],
#        [-1.14740436e+00, -3.37940406e+00, -6.19301243e-01],
#        [-1.24417858e+00, -1.12769769e+00,  3.02187293e-01],
#        [ 9.18834012e-01, -3.43753095e-01, -2.69002212e-02],
#        [ 1.50430804e+00, -1.35460273e+00, -1.36467201e-01],
#        [-3.36384712e-02,  1.57083895e+00,  7.05782950e-01],
#        [ 1.12451133e+00, -1.53982573e+00,  8.50344966e-01],
#        [ 4.33313748e-01, -5.34174641e-01, -4.48635398e-01],
#        [-6.50765632e-01,  4.55773253e-02, -4.94338510e-01],
#        [ 4.33054863e-01,  1.37669821e+00, -1.91009980e-01],
#        [ 1.70006741e+00, -1.54563637e+00, -2.23514471e+00],
#        [ 5.32471975e-03,  1.09421963e+00, -1.44171309e+00],
#        [ 1.72871805e+00, -7.68233363e-02,  1.46490222e+00],
#        [-2.77705154e+00, -1.08414508e+00,  1.74536452e+00],
#        [ 9.28930868e-01,  3.82145857e-01, -1.64772716e-01],
#        [ 1.37635062e-01,  1.14969721e-01,  6.67852846e-01],
#        [-2.78070160e-01, -6.96863303e-01,  4.00286103e-01],
#        [ 1.42710806e-01, -1.63184967e-02,  3.19149196e+00],
#        [-2.09632123e+00, -4.78583941e-01,  1.21549633e+00],
#        [-1.92641359e-01,  2.80835203e-02, -4.26225576e-02],
#        [ 4.28442872e-01,  5.85315439e-01, -8.77295257e-01],
#        [ 1.63530566e+00,  1.52371562e+00, -1.53374568e+00],
#        [-5.14173452e-01, -1.34447845e+00,  2.91581438e-01],
#        [-8.26687363e-01,  2.07932568e+00, -6.76408825e-01],
#        [-4.96391987e-01, -2.06997181e+00, -1.34798408e+00],
#        [ 1.02961169e+00, -2.41386760e-01, -5.65695855e-01],
#        [ 3.97903116e-01,  5.10342378e-01, -1.00437618e+00],
#        [-5.26545922e-01,  1.98189029e-01,  1.78789769e+00],
#        [ 5.96591165e-01, -7.19699143e-01,  9.75534393e-01],
#        [ 1.48435932e-01, -2.98608960e-01,  7.83441066e-02],
#        [ 1.08694387e+00, -5.87963023e-01,  1.57893525e+00],
#        [-7.12071720e-01, -6.85840698e-01,  1.64412006e-01],
#        [-3.08925780e-01,  7.75731994e-01, -7.82236125e-01],
#        [-3.78321544e-01,  2.75406961e-01,  1.62248300e+00],
#        [-1.53201744e+00, -7.91012202e-01,  6.29885243e-01],
#        [ 3.62766081e-01,  8.26515226e-01, -9.59696955e-01],
#        [ 3.25007918e-01,  2.24909969e-01, -1.05575359e-01],
#        [ 4.94085622e-02,  7.38414840e-01, -7.96692277e-01],
#        [-2.08702166e-01,  5.52303010e-01, -1.30819402e+00],
#        [-1.48017553e+00, -9.29235489e-01,  1.02045157e+00],
#        [-4.09050503e-01, -6.56198512e-01,  2.01206608e+00],
#        [-3.25134243e-01,  6.71816260e-01, -1.32409618e+00],
#        [-8.19993586e-01,  5.32741886e-01,  6.54149377e-01],
#        [-1.29770848e-01, -1.08447110e-01, -5.69800207e-01],
#        [ 4.78986239e-01,  3.19534132e-02, -4.04890151e-01],
#        [ 2.07495626e+00,  1.21051956e+00, -5.11055389e-01],
#        [ 2.31888582e-01, -6.88081996e-01, -7.84965748e-01],
#        [ 3.21233845e-01,  4.68474999e-01,  1.35319605e-01],
#        [-3.62613459e-02, -2.92586209e-01, -7.51643648e-01],
#        [-2.02223954e+00, -3.08318081e-01,  3.59145289e-01],
#        [ 1.53521016e-02,  1.02882123e+00,  3.57186131e-02],
#        [ 1.08758543e-01,  7.51166294e-01, -1.54598792e-01],
#        [ 2.69633311e+00,  7.39072529e-01, -8.28909803e-01],
#        [-1.63232828e-01,  1.23877042e+00, -4.95299719e-01],
#        [ 3.68609971e-01, -6.58833492e-02,  8.48210453e-01],
#        [ 6.52457030e-03,  6.05449139e-01,  5.91568756e-01],
#        [-1.21453566e+00, -4.02358132e-01, -8.99497587e-01],
#        [ 1.27449937e+00,  2.42041775e-01,  1.86563097e-01],
#        [ 8.53587410e-01, -2.19404728e-01,  8.44172243e-01],
#        [ 8.95689306e-01,  1.13025929e-02, -1.59724093e+00],
#        [-9.35330340e-01,  5.17289649e-01,  6.34373299e-01],
#        [ 1.55443791e+00, -9.18291899e-01, -5.81883455e-01],
#        [-1.46561748e+00,  2.03804104e+00,  6.61843798e-01],
#        [ 6.75832859e-01, -1.10903884e+00, -6.83376084e-01],
#        [ 2.40259533e+00, -1.32048039e+00, -1.73387177e+00],
#        [-1.02271183e+00,  1.08908737e+00, -1.55502150e+00],
#        [-5.65889703e-01,  7.16882377e-01,  1.34879204e-01],
#        [ 1.51207429e-01,  5.46707440e-01,  3.48319528e-01],
#        [-4.98242595e-01,  5.50999517e-01, -8.25635107e-01],
#        [-1.62585934e+00, -9.96563232e-02,  7.30416772e-01],
#        [ 1.17731303e-01, -9.98567188e-01, -1.58928855e+00],
#        [-1.09999129e+00, -1.02217260e-02,  1.97419813e-02],
#        [ 5.53868935e-01, -7.75016923e-01, -1.13494721e+00],
#        [-9.46137991e-01,  9.03221484e-01, -5.71003912e-01],
#        [ 1.71287906e+00, -2.36584776e-01,  1.34187083e-01],
#        [-7.99508478e-01, -9.25682725e-01, -7.81357871e-01],
#        [-3.02894994e-01, -4.13651896e-01, -3.01446602e-01],
#        [ 9.19901551e-01,  3.32201356e-01,  1.10124926e+00],
#        [-1.28149814e+00, -6.59797692e-01, -4.95421285e-01],
#        [ 2.88832300e-01, -9.22354446e-01,  9.29195358e-01],
#        [ 1.45143986e+00,  1.60298325e-01, -1.05294525e+00],
#        [-1.68704317e+00,  1.61597783e-01,  6.20701812e-01],
#        [ 2.42716979e-01, -6.02124293e-01,  1.54023284e+00],
#        [ 3.23745389e-01, -5.65655366e-01, -2.40631378e+00],
#        [ 8.85772930e-01,  1.48478232e-01, -7.17298701e-01],
#        [-1.28805200e+00, -1.55805057e+00,  6.68372398e-01],
#        [-1.37797155e+00, -1.51679186e+00, -1.18390305e-01],
#        [ 6.05931512e-01, -8.16947971e-01,  4.60692025e-01],
#        [ 3.63696867e-01, -3.04017514e-01, -5.22745388e-01],
#        [ 3.13634253e-01,  2.28574696e-01,  1.73712036e-01],
#        [ 4.16959437e-01,  1.41131657e+00, -7.06186635e-02],
#        [-6.88351465e-01,  7.83916103e-01,  1.26411411e+00],
#        [ 2.93994246e-01, -2.49668284e-01,  3.42972709e-01],
#        [ 3.59484192e-01, -1.06532105e-01,  4.26863087e-01],
#        [-7.25314614e-01, -1.10549603e+00, -3.29000753e-01],
#        [ 2.05297718e+00, -1.06021130e-01, -4.05375087e-01],
#        [ 5.54127896e-01, -3.80410556e-01, -3.49858141e-01],
#        [-1.23889887e+00,  2.40571238e-01,  4.84196822e-01],
#        [ 7.50882395e-01, -9.27443708e-01, -3.38185847e-01],
#        [-1.00563946e+00,  4.40288172e-01,  3.78627875e-01],
#        [ 8.91438788e-01,  1.46960073e+00,  2.17946412e+00],
#        [ 1.29148356e+00, -1.97685902e-01,  9.64929771e-01],
#        [-8.39812230e-01,  3.20805365e-01, -2.42416003e-01],
#        [ 1.08127034e+00,  6.13768839e-01,  1.29783075e+00],
#        [ 4.88386820e-01, -4.94740710e-01, -3.25166777e-01],
#        [ 9.29100632e-01,  1.40395767e-01, -1.96910101e+00],
#        [ 2.08637801e+00, -7.44269319e-02, -9.30288723e-01],
#        [-2.20332715e-01,  1.19934112e-02, -1.80034302e+00],
#        [-7.67724295e-01, -8.72370746e-01, -2.68123083e-01],
#        [-9.13930972e-01, -6.23219329e-02,  1.04959931e-01],
#        [-8.34566001e-01,  4.18604574e-01,  1.77710219e+00],
#        [-3.91211170e-02,  1.38672358e+00,  4.16096864e-01],
#        [ 4.11256426e-01,  8.87123594e-01, -1.34582209e-01],
#        [ 3.41844328e-01,  2.09979130e+00,  9.22855277e-01],
#        [ 9.34617198e-01, -8.66619573e-01, -2.14358552e+00],
#        [ 5.79028665e-02,  7.98807437e-01,  3.24006228e-01],
#        [ 1.60907473e+00,  9.90051101e-02,  8.63816231e-01],
#        [-2.41081360e-01,  2.13698708e+00, -1.40479647e+00],
#        [ 2.97299338e+00, -9.08213622e-01,  1.23988142e+00],
#        [ 7.17623924e-01, -9.40130836e-01,  4.27764445e-01],
#        [-8.79088938e-01, -6.96026123e-01, -3.32440755e-01],
#        [-1.10923973e+00, -2.24447879e+00,  7.24556683e-01],
#        [ 5.63430944e-01, -6.21231669e-01,  2.37641971e+00],
#        [-1.96723415e-01, -8.58275618e-01,  2.69800087e-01],
#        [ 8.12741473e-01,  6.55392819e-02,  3.36719637e-01],
#        [ 5.53486878e-01,  2.59907727e-01, -3.76889163e-01],
#        [-3.45201493e-02,  1.81842790e+00, -7.70698846e-01],
#        [-8.67929108e-01,  8.78137622e-01,  9.23793436e-01],
#        [-1.58729228e+00, -6.73183836e-01, -7.76991451e-01],
#        [-4.36907042e-01, -9.99745716e-01,  1.58560512e-01],
#        [ 9.66076636e-01,  4.12429952e-01, -3.95341564e-01],
#        [ 2.74439523e-01, -1.42819092e+00,  5.69444528e-01],
#        [-1.29751503e+00,  1.77301341e+00,  4.22888963e-01],
#        [ 2.30384407e-01,  1.11075170e+00,  1.13276257e+00],
#        [ 4.58813943e-01, -5.63763450e-01, -4.27976156e-01],
#        [-9.07839495e-01, -1.82726464e+00, -1.85789121e-01],
#        [ 2.09434288e-01,  1.28792424e+00, -9.00716352e-01],
#        [ 1.06581791e-01, -2.03556396e-01, -3.61693175e-01],
#        [-1.18685345e+00,  1.17004497e+00,  4.66899071e-01]])

# %% [markdown]
# # P068 数据降维PCA-自己实现PCA降维算法

# %%
# 预计算：对输入X做标准化处理

# PCA计算步骤：
# 1.计算X_std的协方差矩阵
# 2.计算协方差矩阵的特征向量和对应的特征值
# 3.通过特征值的降序，对特征向量排序
# 4.确定降维后的数量2
# 5.取特征值最大的两个特征向量，创建参数矩阵
# 6.将X_std和W相乘，得到降维后的X_pca

# %%
X_std[:10]
# Out:
# array([[ 0.57876651,  0.27619096, -1.52162464],
#        [-0.10498128,  0.48237717, -0.51809595],
#        [ 0.74133645,  1.01284857,  0.09167303],
#        [ 1.68390811,  0.98313988,  0.13376544],
#        [-0.20823509, -1.48652939, -0.36751455],
#        [-0.20821741, -1.03977521,  0.71454015],
#        [ 1.74440619,  0.4359092 , -0.99032996],
#        [ 0.87027971,  0.43464025, -0.05720764],
#        [-0.46162987,  0.43592181,  0.20770499],
#        [ 0.62813359,  3.82603986,  0.60520558]])

# %%
cov = np.cov(X_std, rowvar=False)

# %%
cov
# Out:
# array([[ 1.00502513,  0.0956248 , -0.1348713 ],
#        [ 0.0956248 ,  1.00502513, -0.03278962],
#        [-0.1348713 , -0.03278962,  1.00502513]])

# %%
eig_vals, eig_vecs = np.linalg.eig(cov)

# %%
eig_vals
# Out:
# array([1.18685219, 0.85399738, 0.9742258 ])

# %%
eig_vecs
# Out:
# array([[ 0.67226955,  0.73695513, -0.07036184],
#        [ 0.45838603, -0.33974121,  0.82125401],
#        [-0.58132254,  0.58435696,  0.56620761]])

# %%
eig_pairs = [
    (
        np.abs(eig_vals[i]),
        eig_vecs[:, i]
    )
    for i in range(len(eig_vals))
]

# %%
eig_pairs
# Out:
# [(1.186852192269717, array([ 0.67226955,  0.45838603, -0.58132254])),
#  (0.8539973831410598, array([ 0.73695513, -0.33974121,  0.58435696])),
#  (0.9742258014736445, array([-0.07036184,  0.82125401,  0.56620761]))]

# %%
eig_pairs.sort(reverse=True)

# %%
eig_pairs
# Out:
# [(1.186852192269717, array([ 0.67226955,  0.45838603, -0.58132254])),
#  (0.9742258014736445, array([-0.07036184,  0.82125401,  0.56620761])),
#  (0.8539973831410598, array([ 0.73695513, -0.33974121,  0.58435696]))]

# %%
W = np.hstack(
    (
        eig_pairs[0][1].reshape(3, 1),
        eig_pairs[1][1].reshape(3, 1),
    )
)

# %%
W
# Out:
# array([[ 0.67226955, -0.07036184],
#        [ 0.45838603,  0.82125401],
#        [-0.58132254,  0.56620761]])

# %%
X_pca = X_std.dot(W)

# %%
X_pca[:10]
# Out:
# array([[ 1.40024388, -0.67545559],
#        [ 0.45172009,  0.11019099],
#        [ 0.90936196,  0.83155012],
#        [ 1.50493688,  0.76466371],
#        [-0.60774993, -1.41425596],
#        [-1.03197495, -0.43469094],
#        [ 1.94822698, -0.32547982],
#        [ 0.81755166,  0.26332417],
#        [-0.23126283,  0.50808781],
#        [ 1.82425867,  3.44062596]])

# %% [markdown]
# # P069 数据降维PCA-组合降维结果和标签数据

# %%
X_pca[:10]
# Out:
# array([[ 1.40024388, -0.67545559],
#        [ 0.45172009,  0.11019099],
#        [ 0.90936196,  0.83155012],
#        [ 1.50493688,  0.76466371],
#        [-0.60774993, -1.41425596],
#        [-1.03197495, -0.43469094],
#        [ 1.94822698, -0.32547982],
#        [ 0.81755166,  0.26332417],
#        [-0.23126283,  0.50808781],
#        [ 1.82425867,  3.44062596]])

# %%
df_pca = pd.DataFrame(
    data=X_pca,
    columns = ["pca_1", "pca_2"]
)

# %%
df_pca.head()
# Out:
#       pca_1     pca_2
# 0  1.400244 -0.675456
# 1  0.451720  0.110191
# 2  0.909362  0.831550
# 3  1.504937  0.764664
# 4 -0.607750 -1.414256

# %%
df_pca["class"] = df["class"]

# %%
df_pca
# Out:
#         pca_1     pca_2  class
# 0    1.400244 -0.675456      2
# 1    0.451720  0.110191      0
# 2    0.909362  0.831550      1
# 3    1.504937  0.764664      2
# 4   -0.607750 -1.414256      2
# ..        ...       ...    ...
# 195  0.298818 -0.737599      1
# 196 -1.339902 -1.541966      1
# 197  1.254769  0.532984      0
# 198  0.188605 -0.379464      2
# 199 -0.532972  1.308775      0
#
# [200 rows x 3 columns]

# %% [markdown]
# # P070 数据降维PCA-使用sklearn的PCA算法

# %%
X_std[:10]
# Out:
# array([[ 0.57876651,  0.27619096, -1.52162464],
#        [-0.10498128,  0.48237717, -0.51809595],
#        [ 0.74133645,  1.01284857,  0.09167303],
#        [ 1.68390811,  0.98313988,  0.13376544],
#        [-0.20823509, -1.48652939, -0.36751455],
#        [-0.20821741, -1.03977521,  0.71454015],
#        [ 1.74440619,  0.4359092 , -0.99032996],
#        [ 0.87027971,  0.43464025, -0.05720764],
#        [-0.46162987,  0.43592181,  0.20770499],
#        [ 0.62813359,  3.82603986,  0.60520558]])

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

# %%
X_pca = pca.fit_transform(X_std)

# %%
X_pca[:10]
# Out:
# array([[ 1.40024388, -0.67545559],
#        [ 0.45172009,  0.11019099],
#        [ 0.90936196,  0.83155012],
#        [ 1.50493688,  0.76466371],
#        [-0.60774993, -1.41425596],
#        [-1.03197495, -0.43469094],
#        [ 1.94822698, -0.32547982],
#        [ 0.81755166,  0.26332417],
#        [-0.23126283,  0.50808781],
#        [ 1.82425867,  3.44062596]])

# %%
df = pd.DataFrame(
    data = X_pca,
    columns = ["pca_1", "pca_2"]
)

# %%
df.head()
# Out:
#       pca_1     pca_2
# 0  1.400244 -0.675456
# 1  0.451720  0.110191
# 2  0.909362  0.831550
# 3  1.504937  0.764664
# 4 -0.607750 -1.414256

# %%
df["class"] = y

# %%
df
# Out:
#         pca_1     pca_2  class
# 0    1.400244 -0.675456      2
# 1    0.451720  0.110191      0
# 2    0.909362  0.831550      1
# 3    1.504937  0.764664      2
# 4   -0.607750 -1.414256      2
# ..        ...       ...    ...
# 195  0.298818 -0.737599      1
# 196 -1.339902 -1.541966      1
# 197  1.254769  0.532984      0
# 198  0.188605 -0.379464      2
# 199 -0.532972  1.308775      0
#
# [200 rows x 3 columns]

# %% [markdown]
# # P071 数据降维PCA-计算观察方差分布

# %%
import numpy as np
import pandas as pd

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
df = pd.read_csv("./p071.csv")

# %%
df.head()
# Out:
#        var_1     var_2     var_3      var_4  var_5     var_6     var_7  \
# 0  13.996714  2.178894  1.702786  17.270966    107  2.979189  2.888065
# 1  13.361736  2.280392  2.200312  12.233504    131  3.278028  2.931631
# 2  14.147689  2.541526  2.502622  17.608818    128  2.729050  4.057878
# 3  15.023030  2.526901  2.523490  19.066914    106  3.319446  3.585941
# 4  13.265847  1.311165  2.274967  16.240305    103  3.783654  2.959527
#
#       var_8     var_9    var_10
# 0  0.302612  1.142997  6.735694
# 1  0.053146  2.004682  4.243828
# 2  0.388645  3.250988  3.809796
# 3  0.070602  0.999803  2.575046
# 4  0.447615  1.458019  7.915910

# %%
data = df.values

# %%
data[:5]
# Out:
# array([[1.39967142e+01, 2.17889368e+00, 1.70278617e+00, 1.72709658e+01,
#         1.07000000e+02, 2.97918925e+00, 2.88806490e+00, 3.02612243e-01,
#         1.14299668e+00, 6.73569389e+00],
#        [1.33617357e+01, 2.28039226e+00, 2.20031249e+00, 1.22335040e+01,
#         1.31000000e+02, 3.27802832e+00, 2.93163073e+00, 5.31457084e-02,
#         2.00468187e+00, 4.24382780e+00],
#        [1.41476885e+01, 2.54152562e+00, 2.50262185e+00, 1.76088178e+01,
#         1.28000000e+02, 2.72905044e+00, 4.05787800e+00, 3.88644820e-01,
#         3.25098849e+00, 3.80979641e+00],
#        [1.50230299e+01, 2.52690103e+00, 2.52349030e+00, 1.90669136e+01,
#         1.06000000e+02, 3.31944552e+00, 3.58594100e+00, 7.06023660e-02,
#         9.99802802e-01, 2.57504595e+00],
#        [1.32658466e+01, 1.31116532e+00, 2.27496726e+00, 1.62403047e+01,
#         1.03000000e+02, 3.78365393e+00, 2.95952694e+00, 4.47614611e-01,
#         1.45801947e+00, 7.91591047e+00]])

# %%
scaler = StandardScaler()
data_std = scaler.fit_transform(data)

# %%
data_std[:5]
# Out:
# array([[ 0.57876651,  0.27619096, -1.52162464,  0.7355021 , -0.60421313,
#         -0.1354866 , -0.52154334,  0.04309511, -1.08345453,  0.79149995],
#        [-0.10498128,  0.48237717, -0.51809595, -0.91554733,  1.02512566,
#          0.42202426, -0.43880483, -2.45542557,  0.00292335, -0.36992773],
#        [ 0.74133645,  1.01284857,  0.09167303,  0.84623449,  0.82145831,
#         -0.60214281,  1.70011979,  0.90475045,  1.5742164 , -0.57222434],
#        [ 1.68390811,  0.98313988,  0.13376544,  1.32413156, -0.67210225,
#          0.49929173,  0.80383555, -2.28058921, -1.26398758, -1.14772612],
#        [-0.20823509, -1.48652939, -0.36751455,  0.39769855, -0.8757696 ,
#          1.3653138 , -0.38582545,  1.49535971, -0.68628651,  1.34158416]])

# %%
pca = PCA(n_components=3)

# %%
data_pca = pca.fit_transform(data_std)

# %%
data_pca[:10]
# Out:
# array([[-0.18418816, -0.9995602 , -0.03114969],
#        [ 0.47785544, -0.43106208, -1.12761124],
#        [ 1.66201618,  0.79798703,  0.48929041],
#        [-1.41856562, -0.39124297, -1.00334242],
#        [-0.95127995, -0.61229063, -0.2061954 ],
#        [-1.50575826, -0.54983598,  1.28598988],
#        [ 1.22904261, -1.39777429,  1.67880378],
#        [ 0.98559739,  0.24608349,  0.17627925],
#        [ 0.51968301, -0.85100247,  0.41956888],
#        [ 0.54877289, -1.07788715, -0.05099202]])

# %%
results = pd.DataFrame(
    data={"variance_ratio":pca.explained_variance_ratio_}, 
)

# %%
results["cumulative"] = results["variance_ratio"].cumsum()

# %%
results["component"] = results.index + 1

# %%
results
# Out:
#    variance_ratio  cumulative  component
# 0        0.138184    0.138184          1
# 1        0.127378    0.265561          2
# 2        0.122946    0.388508          3

# %% [markdown]
# # P072 数据降维PCA-指定方差百分比计算分量数

# %%
# 如果降维后，想保留95%的方差百分比
# 计算对应的降维后分量数目

# %%
data_std[:5]
# Out:
# array([[ 0.57876651,  0.27619096, -1.52162464,  0.7355021 , -0.60421313,
#         -0.1354866 , -0.52154334,  0.04309511, -1.08345453,  0.79149995],
#        [-0.10498128,  0.48237717, -0.51809595, -0.91554733,  1.02512566,
#          0.42202426, -0.43880483, -2.45542557,  0.00292335, -0.36992773],
#        [ 0.74133645,  1.01284857,  0.09167303,  0.84623449,  0.82145831,
#         -0.60214281,  1.70011979,  0.90475045,  1.5742164 , -0.57222434],
#        [ 1.68390811,  0.98313988,  0.13376544,  1.32413156, -0.67210225,
#          0.49929173,  0.80383555, -2.28058921, -1.26398758, -1.14772612],
#        [-0.20823509, -1.48652939, -0.36751455,  0.39769855, -0.8757696 ,
#          1.3653138 , -0.38582545,  1.49535971, -0.68628651,  1.34158416]])

# %%
pca = PCA(n_components=0.95)
data_pca = pca.fit_transform(data_std)

# %%
pca.n_components_
# Out:
# 10

# %%
data_pca[:10]
# Out:
# array([[-0.18418816, -0.9995602 , -0.03114969,  1.34588282, -0.83972814,
#         -0.12250706, -0.76773933,  0.58219552, -0.76031385,  0.80819374],
#        [ 0.47785544, -0.43106208, -1.12761124, -0.73556745,  0.89203511,
#          0.91739116, -0.82250836, -1.61910294, -1.32494589,  0.14251192],
#        [ 1.66201618,  0.79798703,  0.48929041,  0.97079235,  0.84888231,
#          0.308894  ,  1.68651816,  0.00607098,  1.12247666,  0.59214204],
#        [-1.41856562, -0.39124297, -1.00334242,  1.86692035,  0.94433735,
#          2.03673892, -0.35153425, -1.36454481,  0.31130046,  1.12093176],
#        [-0.95127995, -0.61229063, -0.2061954 ,  0.65643496, -1.30022257,
#         -2.14229975, -0.37443913,  0.79811059,  0.38298958, -0.93598398],
#        [-1.50575826, -0.54983598,  1.28598988,  0.03301075, -0.03296738,
#         -0.9465066 ,  2.11224545,  0.37422059, -1.24686109, -0.94096253],
#        [ 1.22904261, -1.39777429,  1.67880378,  0.53777728, -1.38523162,
#          0.92460052,  0.35940551,  0.81609058, -0.15308383, -0.85196817],
#        [ 0.98559739,  0.24608349,  0.17627925,  0.35352084,  0.13425045,
#          0.94902585, -1.27122251,  0.57938222,  0.2942201 , -0.55420642],
#        [ 0.51968301, -0.85100247,  0.41956888, -1.67738139,  0.54754867,
#          0.55369279, -1.03862086,  0.37867295, -1.47787215, -1.06349007],
#        [ 0.54877289, -1.07788715, -0.05099202,  1.2570118 ,  3.19216251,
#          1.42570272, -0.25259316,  1.74013248, -0.07948409,  1.81695838]])
