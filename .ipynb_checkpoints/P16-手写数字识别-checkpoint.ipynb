# %% [markdown]
# # P083 手写数字识别-加载并查看数据

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_digits

# %%
np.random.seed(42)
data, target = load_digits(return_X_y=True)

# %%
data.shape
# Out:
# (1797, 64)

# %%
data
# Out:
# array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#        ...,
#        [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#        [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#        [ 0.,  0., 10., ..., 12.,  1.,  0.]])

# %%
target.shape
# Out:
# (1797,)

# %%
target
# Out:
# array([0, 1, 2, ..., 8, 9, 8])

# %%
data[100].reshape(8,8)
# Out:
# array([[ 0.,  0.,  0.,  2., 13.,  0.,  0.,  0.],
#        [ 0.,  0.,  0.,  8., 15.,  0.,  0.,  0.],
#        [ 0.,  0.,  5., 16.,  5.,  2.,  0.,  0.],
#        [ 0.,  0., 15., 12.,  1., 16.,  4.,  0.],
#        [ 0.,  4., 16.,  2.,  9., 16.,  8.,  0.],
#        [ 0.,  0., 10., 14., 16., 16.,  4.,  0.],
#        [ 0.,  0.,  0.,  0., 13.,  8.,  0.,  0.],
#        [ 0.,  0.,  0.,  0., 13.,  6.,  0.,  0.]])

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(data[100].reshape(8,8), cmap="gray_r")

# %%
target[100]
# Out:
# 4

# %% [markdown]
# # P084 手写数字识别-训练和测试集的拆分

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(data, target,random_state=42)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((1347, 64), (450, 64), (1347,), (450,))

# %% [markdown]
# # P085 手写数字识别-使用K近邻算法做分类

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()

# %%
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
knn.score(x_test, y_test)
# Out:
# 0.9933333333333333

# %%
knn.score(x_train, y_train)
# Out:
# 0.9888641425389755

# %% [markdown]
# # P086 手写数字识别-逻辑回归算法做分类

# %%
# 逻辑回归又叫对数几率回归，是一种广义的线性回归分析模型。虽然名字有回归，但其实是分类模型，常用于二分类。
# 常用于数据挖掘，疾病自动诊断，经济预测等领域

# %%
from sklearn.linear_model import LogisticRegression

# %%
classifier = LogisticRegression(max_iter=10000)

# %%
classifier.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=10000)

# %%
classifier.score(x_test, y_test)
# Out:
# 0.9733333333333334

# %%
classifier.score(x_train, y_train)
# Out:
# 1.0
